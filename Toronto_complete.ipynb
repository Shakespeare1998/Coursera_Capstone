# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakespeare1998/Coursera_Capstone/blob/master/Toronto_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Scraping wiki page for Toronto neighbourhood info**

# %%
import urllib.request
from bs4 import BeautifulSoup


url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(page, 'lxml')
#print(soup.prettify())

# %%
table = soup.find_all('table', class_='wikitable sortable')
type(table[0])
# Out:
# bs4.element.Tag

# %%
postal_code = []
borough = []
neighbourhood = []


for row in table[0].find_all('tr'):
    cells=row.find_all('td')
    if len(cells)==3:
        postal_code.append((cells[0].find(text=True)).strip())
        borough.append((cells[1].find(text=True)).strip())
        neighbourhood.append((cells[2].find(text=True)).strip())

#postal_code

# %% [markdown]
# ### **Converting scraped data into Dataframe**

# %%
import pandas as pd

df=pd.DataFrame(postal_code, columns=["Postal Code"])
df["Borough"] = borough
df["Neighbourhood"] = neighbourhood
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...
# 1           M2A  ...
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...
# 176         M6Z  ...
# 177         M7Z  ...
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Cleaning data

# %%
df = df[df["Borough"]!="Not assigned"]

# %%
df = df.reset_index()

# %%
del df["index"]

# %%
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M3A  ...                                          Parkwoods
# 1           M4A  ...                                   Victoria Village
# 2           M5A  ...                          Regent Park, Harbourfront
# 3           M6A  ...                   Lawrence Manor, Lawrence Heights
# 4           M7A  ...        Queen's Park, Ontario Provincial Government
# ..          ...  ...                                                ...
# 98          M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99          M4Y  ...                               Church and Wellesley
# 100         M7Y  ...              Business reply mail Processing Centre
# 101         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### **Retrieving Location data (Longitudes and Latitiudes)**

# %%
# !git clone https://github.com/Shakespeare1998/Coursera_Capstone
# Out:
# Cloning into 'Coursera_Capstone'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
# !cd Coursera_Capstone

# %%
lo = pd.read_csv("Coursera_Capstone/Geospatial_Coordinates.csv")

# %% [markdown]
# ### Merging the two datasets

# %%
final_df = pd.merge(df, lo, how="inner", left_on="Postal Code", right_on="Postal Code")

# %%
final_df.head(2)
# Out:
#   Postal Code     Borough     Neighbourhood   Latitude  Longitude
# 0         M3A  North York         Parkwoods  43.753259 -79.329656
# 1         M4A  North York  Victoria Village  43.725882 -79.315572

# %% [markdown]
# ### **Creating a map of Toronto**

# %%
import folium
from geopy.geocoders import Nominatim

address = 'Toronto'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
#print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
map_tor = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(final_df['Latitude'], final_df['Longitude'], final_df['Borough'], final_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tor)  
    
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **Exploring and retrieving data from Foursquare**
#
# ---

# %%
import json
import requests
from pandas.io.json import json_normalize 

CLIENT_ID = 'T5BPTTCUI0BGDLUMJNP4WJFT4OFLIZKATZ0JOESYZIGXIGPX' # your Foursquare ID
CLIENT_SECRET = 'EGFOCBEUDL5RNKFRPLD1MW2VCS5310SAQO5JLRANKT5GRJ2K' # your Foursquare Secret
VERSION = '20180605'
venue_name = []
venue_categories = []
venue_location_lat = []
venue_location_lng = []
n = []

for i in final_df.index:
  lat = final_df.loc[i,"Latitude"]
  lng = final_df.loc[i,"Longitude"]
  url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, 750, 50)
  results = requests.get(url).json()
  #print(final_df.loc[i, "Neighbourhood"])
  try:
    data = results['response']['groups'][0]['items']
    for j in data:
      n.append(final_df.loc[i,"Neighbourhood"])
      venue_name.append(j['venue']['name'])
      venue_location_lat.append(j['venue']['location']['lat'])
      venue_location_lng.append(j['venue']['location']['lng'])
      venue_categories.append(j['venue']['categories'][0]['name'])

  except:
     print(final_df.loc[i, "Neighbourhood"] + "Unsuccessful")
print(len(n))
print(len(venue_name))
print(len(venue_location_lat))
print(len(venue_location_lng))
print(len(venue_categories))
# Out:
# Caledonia-FairbanksUnsuccessful
# Golden Mile, Clairlea, OakridgeUnsuccessful
# Steeles West, L'Amoreaux WestUnsuccessful
# 2614
# 2614
# 2614
# 2614
# 2614

# %%
lat = final_df[final_df['Neighbourhood']=="Steeles West, L'Amoreaux West"]['Latitude']
lng = final_df[final_df['Neighbourhood']=="Steeles West, L'Amoreaux West"]['Longitude']
url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, 750, 50)
results = requests.get(url).json()
  #print(final_df.loc[i, "Neighbourhood"])
try:
  data = results['response']
  print(data.keys())
  '''
  for j in data:
    n.append(final_df.loc[i,"Neighbourhood"])
    venue_name.append(j['venue']['name'])
    venue_location_lat.append(j['venue']['location']['lat'])
    venue_location_lng.append(j['venue']['location']['lng'])
    venue_categories.append(j['venue']['categories'][0]['name'])'''

except:
   print( " Unsuccessful")
# Out:
# dict_keys([])

# %%
data_dict = {'Neighbourhood' : n, 'Venue' : venue_name, 'Category' : venue_categories, 'Latitude' : venue_location_lat, 'Longitude' : venue_location_lng}

# %% [markdown]
# ### Creating dataframe with data from Foursquare

# %%
import pandas as pd
nearby = pd.DataFrame.from_dict(data_dict)
nearby.head()
# Out:
#       Neighbourhood                   Venue  ...   Latitude  Longitude
# 0         Parkwoods         Brookbanks Park  ...  43.751976 -79.332140
# 1         Parkwoods           Variety Store  ...  43.751974 -79.333114
# 2         Parkwoods       DVP at York Mills  ...  43.758899 -79.334099
# 3         Parkwoods         TTC Stop #09083  ...  43.759655 -79.332223
# 4  Victoria Village  Victoria Village Arena  ...  43.723481 -79.315635
#
# [5 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)
len(nearby['Category'].unique())
# Out:
# 305

# %% [markdown]
# ### Readying the dataframe for training using onehot encoding

# %%
nearby_onehot = pd.get_dummies(nearby[['Category']], prefix="", prefix_sep="")
nearby_onehot['Neighbourhood'] = nearby['Neighbourhood']
nearby_onehot.head()
# Out:
#    Accessories Store  Afghan Restaurant  ...  Yoga Studio     Neighbourhood
# 0                  0                  0  ...            0         Parkwoods
# 1                  0                  0  ...            0         Parkwoods
# 2                  0                  0  ...            0         Parkwoods
# 3                  0                  0  ...            0         Parkwoods
# 4                  0                  0  ...            0  Victoria Village
#
# [5 rows x 306 columns]

# %%
nearby_onehot_grouped = nearby_onehot.groupby('Neighbourhood').mean().reset_index()
#len(nearby['Neighbourhood'].unique())
nearby_onehot_grouped
# Out:
#                                         Neighbourhood  ...  Yoga Studio
# 0                                           Agincourt  ...     0.000000
# 1                              Alderwood, Long Branch  ...     0.000000
# 2     Bathurst Manor, Wilson Heights, Downsview North  ...     0.000000
# 3                                     Bayview Village  ...     0.000000
# 4                   Bedford Park, Lawrence Manor East  ...     0.000000
# 5                                         Berczy Park  ...     0.000000
# 6                         Birch Cliff, Cliffside West  ...     0.000000
# 7        Brockton, Parkdale Village, Exhibition Place  ...     0.000000
# 8               Business reply mail Processing Centre  ...     0.000000
# 9   CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 10              Canada Post Gateway Processing Centre  ...     0.000000
# 11                                          Cedarbrae  ...     0.052632
# 12                                 Central Bay Street  ...     0.020000
# 13                                           Christie  ...     0.000000
# 14                               Church and Wellesley  ...     0.040000
# 15            Clarks Corners, Tam O'Shanter, Sullivan  ...     0.000000
# 16    Cliffside, Cliffcrest, Scarborough Village West  ...     0.000000
# 17                     Commerce Court, Victoria Hotel  ...     0.000000
# 18                                         Davisville  ...     0.000000
# 19                                   Davisville North  ...     0.000000
# 20   Del Ray, Mount Dennis, Keelsdale and Silverthorn  ...     0.000000
# 21                                          Don Mills  ...     0.000000
# 22  Dorset Park, Wexford Heights, Scarborough Town...  ...     0.000000
# 23                                          Downsview  ...     0.000000
# 24                       Dufferin, Dovercourt Village  ...     0.000000
# 25                                       East Toronto  ...     0.000000
# 26  Eringate, Bloordale Gardens, Old Burnhamthorpe...  ...     0.000000
# 27                       Fairview, Henry Farm, Oriole  ...     0.000000
# 28             First Canadian Place, Underground city  ...     0.000000
# 29                           Forest Hill North & West  ...     0.000000
# 30                           Garden District, Ryerson  ...     0.020000
# 31                                          Glencairn  ...     0.000000
# 32                  Guildwood, Morningside, West Hill  ...     0.000000
# 33  Harbourfront East, Union Station, Toronto Islands  ...     0.020000
# 34                      High Park, The Junction South  ...     0.020000
# 35                                  Hillcrest Village  ...     0.000000
# 36                                      Humber Summit  ...     0.000000
# 37                                   Humberlea, Emery  ...     0.000000
# 38                                 Humewood-Cedarvale  ...     0.000000
# 39                     India Bazaar, The Beaches West  ...     0.000000
# 40                                   Islington Avenue  ...     0.000000
# 41        Kennedy Park, Ionview, East Birchmount Park  ...     0.000000
# 42          Kensington Market, Chinatown, Grange Park  ...     0.020000
# 43  Kingsview Village, St. Phillips, Martin Grove ...  ...     0.000000
# 44                   Lawrence Manor, Lawrence Heights  ...     0.000000
# 45                                      Lawrence Park  ...     0.000000
# 46                                            Leaside  ...     0.000000
# 47                           Little Portugal, Trinity  ...     0.020000
# 48                                     Malvern, Rouge  ...     0.000000
# 49  Milliken, Agincourt North, Steeles East, L'Amo...  ...     0.000000
# 50  Mimico NW, The Queensway West, South of Bloor,...  ...     0.035714
# 51                        Moore Park, Summerhill East  ...     0.000000
# 52       New Toronto, Mimico South, Humber Bay Shores  ...     0.000000
# 53           North Park, Maple Leaf Park, Upwood Park  ...     0.000000
# 54                                 North Toronto West  ...     0.021739
# 55                                          Northwest  ...     0.000000
# 56                    Northwood Park, York University  ...     0.000000
# 57  Old Mill South, King's Mill Park, Sunnylea, Hu...  ...     0.000000
# 58                             Parkdale, Roncesvalles  ...     0.000000
# 59                    Parkview Hill, Woodbine Gardens  ...     0.000000
# 60                                          Parkwoods  ...     0.000000
# 61        Queen's Park, Ontario Provincial Government  ...     0.040000
# 62                          Regent Park, Harbourfront  ...     0.020000
# 63                           Richmond, Adelaide, King  ...     0.020000
# 64                                           Rosedale  ...     0.000000
# 65                                           Roselawn  ...     0.000000
# 66             Rouge Hill, Port Union, Highland Creek  ...     0.000000
# 67                                 Runnymede, Swansea  ...     0.000000
# 68                      Runnymede, The Junction North  ...     0.000000
# 69                                Scarborough Village  ...     0.000000
# 70  South Steeles, Silverstone, Humbergate, Jamest...  ...     0.000000
# 71                                     St. James Town  ...     0.000000
# 72                        St. James Town, Cabbagetown  ...     0.000000
# 73                                     Stn A PO Boxes  ...     0.000000
# 74                                    Studio District  ...     0.020000
# 75  Summerhill West, Rathnelly, South Hill, Forest...  ...     0.020000
# 76                The Annex, North Midtown, Yorkville  ...     0.000000
# 77                                        The Beaches  ...     0.000000
# 78                       The Danforth West, Riverdale  ...     0.040000
# 79      The Kingsway, Montgomery Road, Old Mill North  ...     0.000000
# 80                                   Thorncliffe Park  ...     0.032258
# 81           Toronto Dominion Centre, Design Exchange  ...     0.000000
# 82                     University of Toronto, Harbord  ...     0.020000
# 83                                   Victoria Village  ...     0.000000
# 84  West Deane Park, Princess Gardens, Martin Grov...  ...     0.000000
# 85                                          Westmount  ...     0.000000
# 86                                             Weston  ...     0.000000
# 87                                  Wexford, Maryvale  ...     0.000000
# 88                                         Willowdale  ...     0.000000
# 89                            Willowdale, Newtonbrook  ...     0.000000
# 90                                             Woburn  ...     0.000000
# 91                                   Woodbine Heights  ...     0.000000
# 92                                    York Mills West  ...     0.000000
# 93                           York Mills, Silver Hills  ...     0.000000
#
# [94 rows x 306 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    try:
      return row_categories_sorted.index.values[0:num_top_venues]
    except:
      return row_categories_sorted.index.values[0:]

# %% [markdown]
# ### Finding the top venues for each neighbourhood

# %%
import numpy as np
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = nearby_onehot_grouped['Neighbourhood']

for ind in np.arange(nearby_onehot_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(nearby_onehot_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted
# Out:
#                                         Neighbourhood  ...      10th Most Common Venue
# 0                                           Agincourt  ...   Latin American Restaurant
# 1                              Alderwood, Long Branch  ...                         Gym
# 2     Bathurst Manor, Wilson Heights, Downsview North  ...            Sushi Restaurant
# 3                                     Bayview Village  ...                     Dog Run
# 4                   Bedford Park, Lawrence Manor East  ...                        Café
# 5                                         Berczy Park  ...            Greek Restaurant
# 6                         Birch Cliff, Cliffside West  ...          Falafel Restaurant
# 7        Brockton, Parkdale Village, Exhibition Place  ...                Cocktail Bar
# 8               Business reply mail Processing Centre  ...                 Coffee Shop
# 9   CN Tower, King and Spadina, Railway Lands, Har...  ...                        Pier
# 10              Canada Post Gateway Processing Centre  ...        Gym / Fitness Center
# 11                                          Cedarbrae  ...         Fried Chicken Joint
# 12                                 Central Bay Street  ...        Fast Food Restaurant
# 13                                           Christie  ...                  Restaurant
# 14                               Church and Wellesley  ...                   Bookstore
# 15            Clarks Corners, Tam O'Shanter, Sullivan  ...          Seafood Restaurant
# 16    Cliffside, Cliffcrest, Scarborough Village West  ...                   Drugstore
# 17                     Commerce Court, Victoria Hotel  ...              Ice Cream Shop
# 18                                         Davisville  ...       Indonesian Restaurant
# 19                                   Davisville North  ...           Food & Drink Shop
# 20   Del Ray, Mount Dennis, Keelsdale and Silverthorn  ...         Distribution Center
# 21                                          Don Mills  ...         Sporting Goods Shop
# 22  Dorset Park, Wexford Heights, Scarborough Town...  ...           Electronics Store
# 23                                          Downsview  ...                        Park
# 24                       Dufferin, Dovercourt Village  ...              Ice Cream Shop
# 25                                       East Toronto  ...                 Karaoke Bar
# 26  Eringate, Bloordale Gardens, Old Burnhamthorpe...  ...           Electronics Store
# 27                       Fairview, Henry Farm, Oriole  ...               Grocery Store
# 28             First Canadian Place, Underground city  ...                    Beer Bar
# 29                           Forest Hill North & West  ...                     Dog Run
# 30                           Garden District, Ryerson  ...  Modern European Restaurant
# 31                                          Glencairn  ...                        Park
# 32                  Guildwood, Morningside, West Hill  ...                  Sports Bar
# 33  Harbourfront East, Union Station, Toronto Islands  ...                Dessert Shop
# 34                      High Park, The Junction South  ...          Seafood Restaurant
# 35                                  Hillcrest Village  ...           Recreation Center
# 36                                      Humber Summit  ...                  Donut Shop
# 37                                   Humberlea, Emery  ...                   Drugstore
# 38                                 Humewood-Cedarvale  ...                   Gastropub
# 39                     India Bazaar, The Beaches West  ...                        Park
# 40                                   Islington Avenue  ...            Doner Restaurant
# 41        Kennedy Park, Ionview, East Birchmount Park  ...              Sandwich Place
# 42          Kensington Market, Chinatown, Grange Park  ...                 Supermarket
# 43  Kingsview Village, St. Phillips, Martin Grove ...  ...              Sandwich Place
# 44                   Lawrence Manor, Lawrence Heights  ...                 Event Space
# 45                                      Lawrence Park  ...                  Donut Shop
# 46                                            Leaside  ...                  Sports Bar
# 47                           Little Portugal, Trinity  ...                 Record Shop
# 48                                     Malvern, Rouge  ...         Dumpling Restaurant
# 49  Milliken, Agincourt North, Steeles East, L'Amo...  ...             Udon Restaurant
# 50  Mimico NW, The Queensway West, South of Bloor,...  ...                        Café
# 51                        Moore Park, Summerhill East  ...                     Dog Run
# 52       New Toronto, Mimico South, Humber Bay Shores  ...                      Bakery
# 53           North Park, Maple Leaf Park, Upwood Park  ...           Electronics Store
# 54                                 North Toronto West  ...                      Bakery
# 55                                          Northwest  ...         Dumpling Restaurant
# 56                    Northwood Park, York University  ...                        Bank
# 57  Old Mill South, King's Mill Park, Sunnylea, Hu...  ...                  Donut Shop
# 58                             Parkdale, Roncesvalles  ...                   Bookstore
# 59                    Parkview Hill, Woodbine Gardens  ...                  Restaurant
# 60                                          Parkwoods  ...                   Drugstore
# 61        Queen's Park, Ontario Provincial Government  ...                    Beer Bar
# 62                          Regent Park, Harbourfront  ...                Dessert Shop
# 63                           Richmond, Adelaide, King  ...                  Steakhouse
# 64                                           Rosedale  ...            Doner Restaurant
# 65                                           Roselawn  ...                  Donut Shop
# 66             Rouge Hill, Port Union, Highland Creek  ...           Elementary School
# 67                                 Runnymede, Swansea  ...                   Bookstore
# 68                      Runnymede, The Junction North  ...             Thai Restaurant
# 69                                Scarborough Village  ...              Discount Store
# 70  South Steeles, Silverstone, Humbergate, Jamest...  ...         Fried Chicken Joint
# 71                                     St. James Town  ...                      Museum
# 72                        St. James Town, Cabbagetown  ...                   Gastropub
# 73                                     Stn A PO Boxes  ...                    Tea Room
# 74                                    Studio District  ...            Sushi Restaurant
# 75  Summerhill West, Rathnelly, South Hill, Forest...  ...                        Bank
# 76                The Annex, North Midtown, Yorkville  ...  Modern European Restaurant
# 77                                        The Beaches  ...                      Church
# 78                       The Danforth West, Riverdale  ...                   Bookstore
# 79      The Kingsway, Montgomery Road, Old Mill North  ...                Burger Joint
# 80                                   Thorncliffe Park  ...                      Bridge
# 81           Toronto Dominion Centre, Design Exchange  ...                         Bar
# 82                     University of Toronto, Harbord  ...                 Supermarket
# 83                                   Victoria Village  ...         Dumpling Restaurant
# 84  West Deane Park, Princess Gardens, Martin Grov...  ...  Construction & Landscaping
# 85                                          Westmount  ...                Intersection
# 86                                             Weston  ...                    Dive Bar
# 87                                  Wexford, Maryvale  ...                        Café
# 88                                         Willowdale  ...             Bubble Tea Shop
# 89                            Willowdale, Newtonbrook  ...                 Yoga Studio
# 90                                             Woburn  ...                   Drugstore
# 91                                   Woodbine Heights  ...                        Park
# 92                                    York Mills West  ...                  Donut Shop
# 93                           York Mills, Silver Hills  ...         Dumpling Restaurant
#
# [94 rows x 11 columns]

# %% [markdown]
# ### ***Clustering the data using KMeans***

# %%
from sklearn.cluster import KMeans

neighborhood_cluster = nearby_onehot_grouped.drop('Neighbourhood', axis = 1)

k_cluster = KMeans(n_clusters = 3, random_state=0)
k_cluster.fit(neighborhood_cluster)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
neighborhoods_venues_sorted["Cluster"] = k_cluster.labels_

# %%
#final_df = final_df.drop('Postal Code', axis=1)
end_data = pd.merge(final_df,neighborhoods_venues_sorted, on = 'Neighbourhood')

# %%
end_data['Cluster'].unique()
# Out:
# array([1, 0, 2], dtype=int32)

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

import matplotlib.colors as colors
import matplotlib.cm as cm
# set color scheme for the clusters
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(end_data['Latitude'], end_data['Longitude'], end_data['Neighbourhood'], end_data['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
