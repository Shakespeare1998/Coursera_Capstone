# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakespeare1998/Coursera_Capstone/blob/master/Toronto_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Scraping wiki page for Toronto neighbourhood info**

# %%
import urllib.request
from bs4 import BeautifulSoup


url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(page, 'lxml')
#print(soup.prettify())

# %%
table = soup.find_all('table', class_='wikitable sortable')
type(table[0])
# Out:
# bs4.element.Tag

# %%
postal_code = []
borough = []
neighbourhood = []


for row in table[0].find_all('tr'):
    cells=row.find_all('td')
    if len(cells)==3:
        postal_code.append((cells[0].find(text=True)).strip())
        borough.append((cells[1].find(text=True)).strip())
        neighbourhood.append((cells[2].find(text=True)).strip())

#postal_code

# %% [markdown]
# ### **Converting scraped data into Dataframe**

# %%
import pandas as pd

df=pd.DataFrame(postal_code, columns=["Postal Code"])
df["Borough"] = borough
df["Neighbourhood"] = neighbourhood
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...
# 1           M2A  ...
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...
# 176         M6Z  ...
# 177         M7Z  ...
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Cleaning data

# %%
df = df[df["Borough"]!="Not assigned"]

# %%
df = df.reset_index()

# %%
del df["index"]

# %%
df
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M3A  ...                                          Parkwoods
# 1           M4A  ...                                   Victoria Village
# 2           M5A  ...                          Regent Park, Harbourfront
# 3           M6A  ...                   Lawrence Manor, Lawrence Heights
# 4           M7A  ...        Queen's Park, Ontario Provincial Government
# ..          ...  ...                                                ...
# 98          M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99          M4Y  ...                               Church and Wellesley
# 100         M7Y  ...              Business reply mail Processing Centre
# 101         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### **Retrieving Location data (Longitudes and Latitudes)**

# %% [markdown]
# This the data from the csv file provided. It has been uploaded onto the github repository from which it is being retrieved.

# %%
# !git clone https://github.com/Shakespeare1998/Coursera_Capstone
# Out:
# Cloning into 'Coursera_Capstone'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
# !cd Coursera_Capstone

# %%
lo = pd.read_csv("Coursera_Capstone/Geospatial_Coordinates.csv")

# %% [markdown]
# ### Merging the two datasets

# %%
final_df = pd.merge(df, lo, how="inner", left_on="Postal Code", right_on="Postal Code")

# %%
final_df.head(2)
# Out:
#   Postal Code     Borough     Neighbourhood   Latitude  Longitude
# 0         M3A  North York         Parkwoods  43.753259 -79.329656
# 1         M4A  North York  Victoria Village  43.725882 -79.315572

# %% [markdown]
# ### **Creating a map of Toronto**

# %%
import folium
from geopy.geocoders import Nominatim

address = 'Toronto'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
#print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
map_tor = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(final_df['Latitude'], final_df['Longitude'], final_df['Borough'], final_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tor)  
    
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **Exploring and retrieving data from Foursquare**
#
# ---

# %%
import json
import requests
from pandas.io.json import json_normalize 

CLIENT_ID = 'T5BPTTCUI0BGDLUMJNP4WJFT4OFLIZKATZ0JOESYZIGXIGPX' # your Foursquare ID
CLIENT_SECRET = 'EGFOCBEUDL5RNKFRPLD1MW2VCS5310SAQO5JLRANKT5GRJ2K' # your Foursquare Secret
VERSION = '20180605'
venue_name = []
venue_categories = []
venue_location_lat = []
venue_location_lng = []
n = []

for i in final_df.index:
  lat = final_df.loc[i,"Latitude"]
  lng = final_df.loc[i,"Longitude"]
  url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, 750, 50)
  results = requests.get(url).json()
  #print(final_df.loc[i, "Neighbourhood"])
  try:
    data = results['response']['groups'][0]['items']
    for j in data:
      n.append(final_df.loc[i,"Neighbourhood"])
      venue_name.append(j['venue']['name'])
      venue_location_lat.append(j['venue']['location']['lat'])
      venue_location_lng.append(j['venue']['location']['lng'])
      venue_categories.append(j['venue']['categories'][0]['name'])

  except:
     print(final_df.loc[i, "Neighbourhood"] + "Unsuccessful")
print(len(n))
print(len(venue_name))
print(len(venue_location_lat))
print(len(venue_location_lng))
print(len(venue_categories))
# Out:
# 2661
# 2661
# 2661
# 2661
# 2661

# %%
#lat = final_df[final_df['Neighbourhood']=="Steeles West, L'Amoreaux West"]['Latitude']
#lng = final_df[final_df['Neighbourhood']=="Steeles West, L'Amoreaux West"]['Longitude']
#url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, 750, 50)
#results = requests.get(url).json()
  #print(final_df.loc[i, "Neighbourhood"])
#try:
'''  data = results['response']
  print(data.keys())
  
  for j in data:
    n.append(final_df.loc[i,"Neighbourhood"])
    venue_name.append(j['venue']['name'])
    venue_location_lat.append(j['venue']['location']['lat'])
    venue_location_lng.append(j['venue']['location']['lng'])
    venue_categories.append(j['venue']['categories'][0]['name'])'''

except:
   print( " Unsuccessful")'''
# Out:
# dict_keys([])

# %%
data_dict = {'Neighbourhood' : n, 'Venue' : venue_name, 'Category' : venue_categories, 'Latitude' : venue_location_lat, 'Longitude' : venue_location_lng}

# %% [markdown]
# ### Creating dataframe with data from Foursquare

# %%
import pandas as pd
nearby = pd.DataFrame.from_dict(data_dict)
nearby.head()
# Out:
#       Neighbourhood                   Venue  ...   Latitude  Longitude
# 0         Parkwoods         Brookbanks Park  ...  43.751976 -79.332140
# 1         Parkwoods           Variety Store  ...  43.751974 -79.333114
# 2         Parkwoods       DVP at York Mills  ...  43.758899 -79.334099
# 3         Parkwoods         TTC Stop #09083  ...  43.759655 -79.332223
# 4  Victoria Village  Victoria Village Arena  ...  43.723481 -79.315635
#
# [5 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)
len(nearby['Category'].unique())
# Out:
# 307

# %% [markdown]
# ### Readying the dataframe for training using onehot encoding

# %%
nearby_onehot = pd.get_dummies(nearby[['Category']], prefix="", prefix_sep="")
nearby_onehot['Neighbourhood'] = nearby['Neighbourhood']
nearby_onehot.head()
# Out:
#    Accessories Store  Afghan Restaurant  ...  Yoga Studio     Neighbourhood
# 0                  0                  0  ...            0         Parkwoods
# 1                  0                  0  ...            0         Parkwoods
# 2                  0                  0  ...            0         Parkwoods
# 3                  0                  0  ...            0         Parkwoods
# 4                  0                  0  ...            0  Victoria Village
#
# [5 rows x 308 columns]

# %%
nearby_onehot_grouped = nearby_onehot.groupby('Neighbourhood').mean().reset_index()
#len(nearby['Neighbourhood'].unique())
nearby_onehot_grouped
# Out:
#                                         Neighbourhood  ...  Yoga Studio
# 0                                           Agincourt  ...     0.000000
# 1                              Alderwood, Long Branch  ...     0.000000
# 2     Bathurst Manor, Wilson Heights, Downsview North  ...     0.000000
# 3                                     Bayview Village  ...     0.000000
# 4                   Bedford Park, Lawrence Manor East  ...     0.000000
# 5                                         Berczy Park  ...     0.000000
# 6                         Birch Cliff, Cliffside West  ...     0.000000
# 7        Brockton, Parkdale Village, Exhibition Place  ...     0.000000
# 8               Business reply mail Processing Centre  ...     0.000000
# 9   CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 10                                Caledonia-Fairbanks  ...     0.000000
# 11              Canada Post Gateway Processing Centre  ...     0.000000
# 12                                          Cedarbrae  ...     0.052632
# 13                                 Central Bay Street  ...     0.020000
# 14                                           Christie  ...     0.000000
# 15                               Church and Wellesley  ...     0.040000
# 16            Clarks Corners, Tam O'Shanter, Sullivan  ...     0.000000
# 17    Cliffside, Cliffcrest, Scarborough Village West  ...     0.000000
# 18                     Commerce Court, Victoria Hotel  ...     0.000000
# 19                                         Davisville  ...     0.000000
# 20                                   Davisville North  ...     0.000000
# 21   Del Ray, Mount Dennis, Keelsdale and Silverthorn  ...     0.000000
# 22                                          Don Mills  ...     0.000000
# 23  Dorset Park, Wexford Heights, Scarborough Town...  ...     0.000000
# 24                                          Downsview  ...     0.000000
# 25                       Dufferin, Dovercourt Village  ...     0.000000
# 26                                       East Toronto  ...     0.000000
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...  ...     0.000000
# 28                       Fairview, Henry Farm, Oriole  ...     0.000000
# 29             First Canadian Place, Underground city  ...     0.000000
# 30                           Forest Hill North & West  ...     0.000000
# 31                           Garden District, Ryerson  ...     0.020000
# 32                                          Glencairn  ...     0.000000
# 33                    Golden Mile, Clairlea, Oakridge  ...     0.000000
# 34                  Guildwood, Morningside, West Hill  ...     0.000000
# 35  Harbourfront East, Union Station, Toronto Islands  ...     0.020000
# 36                      High Park, The Junction South  ...     0.020000
# 37                                  Hillcrest Village  ...     0.000000
# 38                                      Humber Summit  ...     0.000000
# 39                                   Humberlea, Emery  ...     0.000000
# 40                                 Humewood-Cedarvale  ...     0.000000
# 41                     India Bazaar, The Beaches West  ...     0.000000
# 42                                   Islington Avenue  ...     0.000000
# 43        Kennedy Park, Ionview, East Birchmount Park  ...     0.000000
# 44          Kensington Market, Chinatown, Grange Park  ...     0.020000
# 45  Kingsview Village, St. Phillips, Martin Grove ...  ...     0.000000
# 46                   Lawrence Manor, Lawrence Heights  ...     0.000000
# 47                                      Lawrence Park  ...     0.000000
# 48                                            Leaside  ...     0.000000
# 49                           Little Portugal, Trinity  ...     0.020000
# 50                                     Malvern, Rouge  ...     0.000000
# 51  Milliken, Agincourt North, Steeles East, L'Amo...  ...     0.000000
# 52  Mimico NW, The Queensway West, South of Bloor,...  ...     0.035714
# 53                        Moore Park, Summerhill East  ...     0.000000
# 54       New Toronto, Mimico South, Humber Bay Shores  ...     0.000000
# 55           North Park, Maple Leaf Park, Upwood Park  ...     0.000000
# 56                                 North Toronto West  ...     0.021739
# 57                                          Northwest  ...     0.000000
# 58                    Northwood Park, York University  ...     0.000000
# 59  Old Mill South, King's Mill Park, Sunnylea, Hu...  ...     0.000000
# 60                             Parkdale, Roncesvalles  ...     0.000000
# 61                    Parkview Hill, Woodbine Gardens  ...     0.000000
# 62                                          Parkwoods  ...     0.000000
# 63        Queen's Park, Ontario Provincial Government  ...     0.040000
# 64                          Regent Park, Harbourfront  ...     0.020000
# 65                           Richmond, Adelaide, King  ...     0.020000
# 66                                           Rosedale  ...     0.000000
# 67                                           Roselawn  ...     0.000000
# 68             Rouge Hill, Port Union, Highland Creek  ...     0.000000
# 69                                 Runnymede, Swansea  ...     0.000000
# 70                      Runnymede, The Junction North  ...     0.000000
# 71                                Scarborough Village  ...     0.000000
# 72  South Steeles, Silverstone, Humbergate, Jamest...  ...     0.000000
# 73                                     St. James Town  ...     0.000000
# 74                        St. James Town, Cabbagetown  ...     0.000000
# 75                      Steeles West, L'Amoreaux West  ...     0.000000
# 76                                     Stn A PO Boxes  ...     0.000000
# 77                                    Studio District  ...     0.020000
# 78  Summerhill West, Rathnelly, South Hill, Forest...  ...     0.020000
# 79                The Annex, North Midtown, Yorkville  ...     0.000000
# 80                                        The Beaches  ...     0.000000
# 81                       The Danforth West, Riverdale  ...     0.040000
# 82      The Kingsway, Montgomery Road, Old Mill North  ...     0.000000
# 83                                   Thorncliffe Park  ...     0.032258
# 84           Toronto Dominion Centre, Design Exchange  ...     0.000000
# 85                     University of Toronto, Harbord  ...     0.020000
# 86                                   Victoria Village  ...     0.000000
# 87  West Deane Park, Princess Gardens, Martin Grov...  ...     0.000000
# 88                                          Westmount  ...     0.000000
# 89                                             Weston  ...     0.000000
# 90                                  Wexford, Maryvale  ...     0.000000
# 91                                         Willowdale  ...     0.000000
# 92                            Willowdale, Newtonbrook  ...     0.000000
# 93                                             Woburn  ...     0.000000
# 94                                   Woodbine Heights  ...     0.000000
# 95                                    York Mills West  ...     0.000000
# 96                           York Mills, Silver Hills  ...     0.000000
#
# [97 rows x 308 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    try:
      return row_categories_sorted.index.values[0:num_top_venues]
    except:
      return row_categories_sorted.index.values[0:]

# %% [markdown]
# ### Finding the top venues for each neighbourhood

# %%
import numpy as np
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = nearby_onehot_grouped['Neighbourhood']

for ind in np.arange(nearby_onehot_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(nearby_onehot_grouped.iloc[ind, :], num_top_venues)

# %%
neighborhoods_venues_sorted
# Out:
#                                         Neighbourhood  ...       10th Most Common Venue
# 0                                           Agincourt  ...                  Supermarket
# 1                              Alderwood, Long Branch  ...                          Pub
# 2     Bathurst Manor, Wilson Heights, Downsview North  ...             Sushi Restaurant
# 3                                     Bayview Village  ...                      Dog Run
# 4                   Bedford Park, Lawrence Manor East  ...                 Intersection
# 5                                         Berczy Park  ...             Greek Restaurant
# 6                         Birch Cliff, Cliffside West  ...              Coworking Space
# 7        Brockton, Parkdale Village, Exhibition Place  ...                         Food
# 8               Business reply mail Processing Centre  ...           Italian Restaurant
# 9   CN Tower, King and Spadina, Railway Lands, Har...  ...                         Park
# 10                                Caledonia-Fairbanks  ...                Grocery Store
# 11              Canada Post Gateway Processing Centre  ...               Breakfast Spot
# 12                                          Cedarbrae  ...          Fried Chicken Joint
# 13                                 Central Bay Street  ...                Shopping Mall
# 14                                           Christie  ...                   Baby Store
# 15                               Church and Wellesley  ...               Breakfast Spot
# 16            Clarks Corners, Tam O'Shanter, Sullivan  ...              Thai Restaurant
# 17    Cliffside, Cliffcrest, Scarborough Village West  ...                    Drugstore
# 18                     Commerce Court, Victoria Hotel  ...                     Fountain
# 19                                         Davisville  ...             Ramen Restaurant
# 20                                   Davisville North  ...               Sandwich Place
# 21   Del Ray, Mount Dennis, Keelsdale and Silverthorn  ...          Distribution Center
# 22                                          Don Mills  ...                  Supermarket
# 23  Dorset Park, Wexford Heights, Scarborough Town...  ...                       Bakery
# 24                                          Downsview  ...               Discount Store
# 25                       Dufferin, Dovercourt Village  ...    Middle Eastern Restaurant
# 26                                       East Toronto  ...                    Bookstore
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...  ...                    Pet Store
# 28                       Fairview, Henry Farm, Oriole  ...                       Bakery
# 29             First Canadian Place, Underground city  ...                   Steakhouse
# 30                           Forest Hill North & West  ...                      Dog Run
# 31                           Garden District, Ryerson  ...               Sandwich Place
# 32                                          Glencairn  ...          Japanese Restaurant
# 33                    Golden Mile, Clairlea, Oakridge  ...                  Bus Station
# 34                  Guildwood, Morningside, West Hill  ...                   Beer Store
# 35  Harbourfront East, Union Station, Toronto Islands  ...               Scenic Lookout
# 36                      High Park, The Junction South  ...                    Bookstore
# 37                                  Hillcrest Village  ...            Recreation Center
# 38                                      Humber Summit  ...                   Donut Shop
# 39                                   Humberlea, Emery  ...             Doner Restaurant
# 40                                 Humewood-Cedarvale  ...                    Gastropub
# 41                     India Bazaar, The Beaches West  ...                   Skate Park
# 42                                   Islington Avenue  ...            Electronics Store
# 43        Kennedy Park, Ionview, East Birchmount Park  ...                  Bus Station
# 44          Kensington Market, Chinatown, Grange Park  ...               Sandwich Place
# 45  Kingsview Village, St. Phillips, Martin Grove ...  ...                  Supermarket
# 46                   Lawrence Manor, Lawrence Heights  ...             Sushi Restaurant
# 47                                      Lawrence Park  ...                   Donut Shop
# 48                                            Leaside  ...                         Bank
# 49                           Little Portugal, Trinity  ...                         Park
# 50                                     Malvern, Rouge  ...          Dumpling Restaurant
# 51  Milliken, Agincourt North, Steeles East, L'Amo...  ...                       Bakery
# 52  Mimico NW, The Queensway West, South of Bloor,...  ...               Sandwich Place
# 53                        Moore Park, Summerhill East  ...                      Dog Run
# 54       New Toronto, Mimico South, Humber Bay Shores  ...                 Dessert Shop
# 55           North Park, Maple Leaf Park, Upwood Park  ...          Dumpling Restaurant
# 56                                 North Toronto West  ...                       Bakery
# 57                                          Northwest  ...          Dumpling Restaurant
# 58                    Northwood Park, York University  ...           Falafel Restaurant
# 59  Old Mill South, King's Mill Park, Sunnylea, Hu...  ...                    Drugstore
# 60                             Parkdale, Roncesvalles  ...                    Gift Shop
# 61                    Parkview Hill, Woodbine Gardens  ...                   Restaurant
# 62                                          Parkwoods  ...                   Donut Shop
# 63        Queen's Park, Ontario Provincial Government  ...          Fried Chicken Joint
# 64                          Regent Park, Harbourfront  ...                 Dessert Shop
# 65                           Richmond, Adelaide, King  ...                   Steakhouse
# 66                                           Rosedale  ...             Doner Restaurant
# 67                                           Roselawn  ...             Doner Restaurant
# 68             Rouge Hill, Port Union, Highland Creek  ...  Eastern European Restaurant
# 69                                 Runnymede, Swansea  ...                    Bookstore
# 70                      Runnymede, The Junction North  ...               Sandwich Place
# 71                                Scarborough Village  ...                        Diner
# 72  South Steeles, Silverstone, Humbergate, Jamest...  ...                     Gym Pool
# 73                                     St. James Town  ...               Farmers Market
# 74                        St. James Town, Cabbagetown  ...          Japanese Restaurant
# 75                      Steeles West, L'Amoreaux West  ...               Discount Store
# 76                                     Stn A PO Boxes  ...                     Tea Room
# 77                                    Studio District  ...    Middle Eastern Restaurant
# 78  Summerhill West, Rathnelly, South Hill, Forest...  ...                Grocery Store
# 79                The Annex, North Midtown, Yorkville  ...                       Bakery
# 80                                        The Beaches  ...                       Church
# 81                       The Danforth West, Riverdale  ...           Frozen Yogurt Shop
# 82      The Kingsway, Montgomery Road, Old Mill North  ...                 Burger Joint
# 83                                   Thorncliffe Park  ...                       Bridge
# 84           Toronto Dominion Centre, Design Exchange  ...     Mediterranean Restaurant
# 85                     University of Toronto, Harbord  ...                          Bar
# 86                                   Victoria Village  ...  Eastern European Restaurant
# 87  West Deane Park, Princess Gardens, Martin Grov...  ...                   Donut Shop
# 88                                          Westmount  ...               Discount Store
# 89                                             Weston  ...                     Dive Bar
# 90                                  Wexford, Maryvale  ...                         Café
# 91                                         Willowdale  ...                   Restaurant
# 92                            Willowdale, Newtonbrook  ...            Electronics Store
# 93                                             Woburn  ...                    Drugstore
# 94                                   Woodbine Heights  ...                  Curling Ice
# 95                                    York Mills West  ...                   Donut Shop
# 96                           York Mills, Silver Hills  ...          Dumpling Restaurant
#
# [97 rows x 11 columns]

# %% [markdown]
# ### ***Clustering the data using KMeans***

# %%
from sklearn.cluster import KMeans

neighborhood_cluster = nearby_onehot_grouped.drop('Neighbourhood', axis = 1)

k_cluster = KMeans(n_clusters = 5, random_state=0)
k_cluster.fit(neighborhood_cluster)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
neighborhoods_venues_sorted["Cluster"] = k_cluster.labels_

# %%
#final_df = final_df.drop('Postal Code', axis=1)
end_data = pd.merge(final_df,neighborhoods_venues_sorted, on = 'Neighbourhood')

# %%
end_data['Cluster'].unique()
# Out:
# array([1, 0, 3, 2, 4], dtype=int32)

# %% [markdown]
# ### **Creating map of Toronto with clusters**

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

import matplotlib.colors as colors
import matplotlib.cm as cm
# set color scheme for the clusters
x = np.arange(5)
ys = [i + x + (i*x)**2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(end_data['Latitude'], end_data['Longitude'], end_data['Neighbourhood'], end_data['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analyzing the clusters

# %%
end_data[end_data['Cluster']==0].iloc[:,5:-1]
# Out:
#       1st Most Common Venue  ...       10th Most Common Venue
# 1                Playground  ...  Eastern European Restaurant
# 2               Coffee Shop  ...                 Dessert Shop
# 3            Clothing Store  ...             Sushi Restaurant
# 4               Coffee Shop  ...          Fried Chicken Joint
# 5                  Pharmacy  ...            Electronics Store
# 6      Fast Food Restaurant  ...          Dumpling Restaurant
# 7       Japanese Restaurant  ...                  Supermarket
# 8       Japanese Restaurant  ...                  Supermarket
# 9      Fast Food Restaurant  ...                   Restaurant
# 10              Coffee Shop  ...               Sandwich Place
# 11            Grocery Store  ...          Japanese Restaurant
# 12              Pizza Place  ...                   Donut Shop
# 13           Breakfast Spot  ...  Eastern European Restaurant
# 14                      Spa  ...                  Curling Ice
# 15                     Café  ...               Farmers Market
# 16              Pizza Place  ...                    Gastropub
# 17                     Park  ...                    Pet Store
# 18              Pizza Place  ...                   Beer Store
# 19                      Pub  ...                       Church
# 20              Coffee Shop  ...             Greek Restaurant
# 21                     Park  ...                Grocery Store
# 23              Coffee Shop  ...                         Bank
# 24              Coffee Shop  ...                Shopping Mall
# 25            Grocery Store  ...                   Baby Store
# 26              Coffee Shop  ...          Fried Chicken Joint
# 27                 Pharmacy  ...            Recreation Center
# 28              Coffee Shop  ...             Sushi Restaurant
# 29        Indian Restaurant  ...                       Bridge
# 30              Coffee Shop  ...                   Steakhouse
# 31              Coffee Shop  ...    Middle Eastern Restaurant
# 32           Ice Cream Shop  ...                        Diner
# 33           Clothing Store  ...                       Bakery
# 34     Fast Food Restaurant  ...           Falafel Restaurant
# 35                     Café  ...                    Bookstore
# 36              Coffee Shop  ...               Scenic Lookout
# 37                      Bar  ...                         Park
# 38              Coffee Shop  ...                  Bus Station
# 39      Japanese Restaurant  ...                      Dog Run
# 40            Grocery Store  ...               Discount Store
# 41            Grocery Store  ...               Discount Store
# 42            Grocery Store  ...               Discount Store
# 43            Grocery Store  ...               Discount Store
# 44         Greek Restaurant  ...           Frozen Yogurt Shop
# 45                     Café  ...     Mediterranean Restaurant
# 46                     Café  ...                         Food
# 47             Intersection  ...                  Bus Station
# 49        Indian Restaurant  ...                   Skate Park
# 50                     Café  ...                     Fountain
# 51             Home Service  ...          Dumpling Restaurant
# 52              Pizza Place  ...                   Donut Shop
# 53           Hardware Store  ...                    Drugstore
# 54              Pizza Place  ...            Electronics Store
# 55                     Café  ...    Middle Eastern Restaurant
# 56       Italian Restaurant  ...                 Intersection
# 57           Sandwich Place  ...          Distribution Center
# 58   Furniture / Home Store  ...             Doner Restaurant
# 60              Coffee Shop  ...                   Restaurant
# 61              Coffee Shop  ...                   Restaurant
# 64   Furniture / Home Store  ...               Sandwich Place
# 65                     Café  ...                     Dive Bar
# 66        Indian Restaurant  ...                       Bakery
# 68              Coffee Shop  ...               Sandwich Place
# 70                     Café  ...                    Bookstore
# 71              Pizza Place  ...               Discount Store
# 72             Burger Joint  ...                         Café
# 73              Coffee Shop  ...                       Bakery
# 74                     Café  ...                       Bakery
# 75                      Bar  ...                    Gift Shop
# 76              Coffee Shop  ...               Breakfast Spot
# 77                 Pharmacy  ...                  Supermarket
# 78              Fabric Shop  ...                  Supermarket
# 79       Italian Restaurant  ...             Ramen Restaurant
# 80                Bookstore  ...                          Bar
# 81                     Café  ...                    Bookstore
# 82                 Pharmacy  ...              Thai Restaurant
# 84                     Café  ...               Sandwich Place
# 85              Pizza Place  ...                       Bakery
# 86              Coffee Shop  ...                Grocery Store
# 87          Airport Service  ...                         Park
# 88                 Pharmacy  ...                 Dessert Shop
# 89            Grocery Store  ...                     Gym Pool
# 90              Pizza Place  ...               Discount Store
# 92              Coffee Shop  ...                     Tea Room
# 93              Pizza Place  ...                          Pub
# 94      Rental Car Location  ...          Dumpling Restaurant
# 95              Coffee Shop  ...          Japanese Restaurant
# 96                     Café  ...                   Steakhouse
# 97                     Park  ...                 Burger Joint
# 98              Coffee Shop  ...               Breakfast Spot
# 99     Fast Food Restaurant  ...           Italian Restaurant
# 101    Gym / Fitness Center  ...               Sandwich Place
#
# [91 rows x 10 columns]

# %% [markdown]
# We can clearly see the common venues in the above cluster

# %% [markdown]
# # This also shows the general necesseties of the public in general

# %%
end_data[end_data['Cluster']==1].iloc[:,5:-1]
# Out:
#     1st Most Common Venue  ... 10th Most Common Venue
# 0       Food & Drink Shop  ...             Donut Shop
# 59                   Park  ...        Coworking Space
# 67                   Park  ...             Donut Shop
# 69   Gym / Fitness Center  ...                Dog Run
# 83                   Park  ...                Dog Run
# 91                   Park  ...       Doner Restaurant
# 100        Baseball Field  ...              Drugstore
#
# [7 rows x 10 columns]

# %%
end_data[end_data['Cluster']==2].iloc[:,5:-1]
# Out:
#    1st Most Common Venue  ... 10th Most Common Venue
# 48                  Pool  ...    Dumpling Restaurant
#
# [1 rows x 10 columns]

# %%
end_data[end_data['Cluster']==3].iloc[:,5:-1]
# Out:
#    1st Most Common Venue  ... 10th Most Common Venue
# 22           Coffee Shop  ...              Drugstore
# 62              Bus Line  ...             Donut Shop
#
# [2 rows x 10 columns]

# %%
end_data[end_data['Cluster']==4].iloc[:,5:-1]
# Out:
#    1st Most Common Venue  ... 10th Most Common Venue
# 63            Playground  ...       Doner Restaurant
#
# [1 rows x 10 columns]

# %% [markdown]
# We can see why this one neighbourhood is in a different cluster from the very different top venues
